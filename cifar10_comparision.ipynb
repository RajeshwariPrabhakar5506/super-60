# %%
import numpy as np
from keras.models import Sequential 
from keras.layers import Dense ,Flatten
from keras.utils import to_categorical              
from keras.datasets import cifar10
import matplotlib.pyplot as plt
from keras.optimizers import Adam,SGD,RMSprop

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print(X_train.dtype, X_train.shape, y_train.dtype, y_train.shape)
# Out:
# uint8 (50000, 32, 32, 3) uint8 (50000, 1)

# %%
#load data

plt.imshow(X_train[0])
plt.show()
print(f"label is {y_train[0]}")
# Out:
# label is [6]

# %%
plt.show()
print(f"label is {y_train[1]}")#method broadcasting to normalize data
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

#to categorical conversion
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# label is [9]

# %%
model=Sequential()
model.add(Flatten(input_shape=(32,32,3)))#1st layer
model.add(Dense(128,activation='relu'))#128 neuron 2nd layer
model.add(Dense(10,activation='softmax'))#3rd layer
# compile the model
model.compile(optimizer=SGD(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy']) 
#train the model
res=model.fit(X_train, y_train, epochs=10, batch_size=128,validation_split=0.2)
print("Code executed successfully")
# validation
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Validation loss: {loss}")
print(f"Validation accuracy: {accuracy}")
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1921 - loss: 2.2238 - val_accuracy: 0.2321 - val_loss: 2.1473
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2550 - loss: 2.1001 - val_accuracy: 0.2652 - val_loss: 2.0709
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2819 - loss: 2.0381 - val_accuracy: 0.2815 - val_loss: 2.0247
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2989 - loss: 1.9971 - val_accuracy: 0.2984 - val_loss: 1.9909
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3107 - loss: 1.9658 - val_accuracy: 0.3084 - val_loss: 1.9652
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3220 - loss: 1.9404 - val_accuracy: 0.3175 - val_loss: 1.9442
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3301 - loss: 1.9202 - val_accuracy: 0.3228 - val_loss: 1.9273
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3380 - loss: 1.9028 - val_accuracy: 0.3287 - val_loss: 1.9149
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3441 - loss: 1.8882 - val_accuracy: 0.3332 - val_loss: 1.9016
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3488 - loss: 1.8756 - val_accuracy: 0.3421 - val_loss: 1.8906
# Code executed successfully
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3524 - loss: 1.8743
# Validation loss: 1.8742526769638062
# Validation accuracy: 0.352400004863739

# %%
model1= Sequential()
model1.add(Flatten(input_shape=(32, 32, 3)))  # 1. Flatten layer (input)
model1.add(Dense(10, activation='softmax'))   # 2. Dense layer (single output layer)


# compile the model
model1.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy', metrics=['accuracy'])

res1=model1.fit(X_train, y_train, epochs=10, batch_size=128,validation_split=0.2)
print("Code executed successfully")
# validation
loss, accuracy = model1.evaluate(X_test, y_test)
print(f"Validation loss: {loss}")
print(f"Validation accuracy: {accuracy}")
# Out:
# C:\Users\Raj\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3107 - loss: 1.9413 - val_accuracy: 0.3336 - val_loss: 1.8885
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3600 - loss: 1.8326 - val_accuracy: 0.3727 - val_loss: 1.8164
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3767 - loss: 1.7929 - val_accuracy: 0.3513 - val_loss: 1.9336
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3788 - loss: 1.7827 - val_accuracy: 0.3826 - val_loss: 1.7812
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3884 - loss: 1.7657 - val_accuracy: 0.3586 - val_loss: 1.8548
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3945 - loss: 1.7511 - val_accuracy: 0.3599 - val_loss: 1.8131
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3930 - loss: 1.7524 - val_accuracy: 0.3881 - val_loss: 1.7676
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3943 - loss: 1.7461 - val_accuracy: 0.3841 - val_loss: 1.7947
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3937 - loss: 1.7463 - val_accuracy: 0.3805 - val_loss: 1.8039
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4001 - loss: 1.7391 - val_accuracy: 0.3741 - val_loss: 1.8053
# Code executed successfully
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3803 - loss: 1.7867
# Validation loss: 1.7866560220718384
# Validation accuracy: 0.38029998540878296

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3))) 
model.add(Dense(1024, activation='relu')) # Layer 1: Input layer
model.add(Dense(256, activation='relu'))   # Layer 2: 1st Hidden layer
model.add(Dense(128, activation='relu'))   # Layer 3: 2nd Hidden layer
model.add(Dense(64, activation='relu'))    # Layer 4: 3rd Hidden layer
model.add(Dense(10, activation='softmax'))    # Layer 5: Output layer

# compile the model
# Using 'Adam' optimizer as an example
model.compile(optimizer=RMSprop(learning_rate=0.001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
res2=model.fit(X_train, y_train, epochs=10, batch_size=128,validation_split=0.2)
print("Code executed successfully")
# validation
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Validation loss: {loss}")
print(f"Validation accuracy: {accuracy}")
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 56ms/step - accuracy: 0.2312 - loss: 2.1006 - val_accuracy: 0.2370 - val_loss: 2.1301
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.3282 - loss: 1.8569 - val_accuracy: 0.3650 - val_loss: 1.7689
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step - accuracy: 0.3688 - loss: 1.7595 - val_accuracy: 0.3833 - val_loss: 1.7232
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.3936 - loss: 1.6894 - val_accuracy: 0.3456 - val_loss: 1.8818
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 68ms/step - accuracy: 0.4157 - loss: 1.6300 - val_accuracy: 0.3960 - val_loss: 1.6929
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.4342 - loss: 1.5834 - val_accuracy: 0.3957 - val_loss: 1.6731
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 68ms/step - accuracy: 0.4457 - loss: 1.5476 - val_accuracy: 0.3854 - val_loss: 1.7051
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.4585 - loss: 1.5144 - val_accuracy: 0.4415 - val_loss: 1.5981
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.4711 - loss: 1.4781 - val_accuracy: 0.4221 - val_loss: 1.6155
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.4809 - loss: 1.4490 - val_accuracy: 0.4529 - val_loss: 1.5269
# Code executed successfully
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.4601 - loss: 1.5038
# Validation loss: 1.503848671913147
# Validation accuracy: 0.460099995136261

# %%
import matplotlib.pyplot as plt

# Create a figure and a 2x3 grid of subplots
# 'axes' will be a 2D array: axes[row, col]
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 10))

# Add a main title for the whole figure
fig.suptitle('Model Comparison: 3-Layer vs 1-Layer vs 5-Layer', fontsize=16)

# --- 3-Layer Model (res) ---

# Plot 1: 3-Layer Accuracy
axes[0, 0].plot(res.history['val_accuracy'], label='Val Accuracy', color='blue')
axes[0, 0].plot(res.history['accuracy'], label='Training Accuracy', color='green')
axes[0, 0].legend()
axes[0, 0].set_title('3-Layer(SGD): Training vs Validation Accuracy')
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Accuracy')

# Plot 4: 3-Layer Loss
axes[1, 0].plot(res.history['val_loss'], label='Val Loss', color='blue')
axes[1, 0].plot(res.history['loss'], label='Training Loss', color='green')
axes[1, 0].legend()
axes[1, 0].set_title('3-Layer(SGD): Training vs Validation Loss')
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Loss')

# --- 1-Layer Model (res1) ---

# Plot 2: 1-Layer Accuracy
axes[0, 1].plot(res1.history['val_accuracy'], label='Val Accuracy', color='blue')
axes[0, 1].plot(res1.history['accuracy'], label='Training Accuracy', color='green')
axes[0, 1].legend()
axes[0, 1].set_title('1-Layer(Adam): Training vs Validation Accuracy')
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')

# Plot 5: 1-Layer Loss
axes[1, 1].plot(res1.history['val_loss'], label='Val Loss', color='blue')
axes[1, 1].plot(res1.history['loss'], label='Training Loss', color='green')
axes[1, 1].legend()
axes[1, 1].set_title('1-Layer(Adam): Training vs Validation Loss')
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Loss')

# --- 5-Layer Model (res2) ---

# Plot 3: 5-Layer Accuracy
axes[0, 2].plot(res2.history['val_accuracy'], label='Val Accuracy', color='blue')
axes[0, 2].plot(res2.history['accuracy'], label='Training Accuracy', color='green')
axes[0, 2].legend()
axes[0, 2].set_title('5-Layer(RMSprop): Training vs Validation Accuracy')
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Accuracy')

# Plot 6: 5-Layer Loss
axes[1, 2].plot(res2.history['val_loss'], label='Val Loss', color='blue')
axes[1, 2].plot(res2.history['loss'], label='Training Loss', color='green')
axes[1, 2].legend()
axes[1, 2].set_title('5-Layer(RMSprop): Training vs Validation Loss')
axes[1, 2].set_xlabel('Epochs')
axes[1, 2].set_ylabel('Loss')

# Automatically adjust spacing to prevent titles/labels from overlapping
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust for the main title

# Show the plot
plt.show()
