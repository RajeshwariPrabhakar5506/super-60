# %%
import numpy as np
from keras.models import Sequential 
from keras.layers import Dense ,Flatten
from keras.utils import to_categorical              
from keras.datasets import cifar10
import matplotlib.pyplot as plt
from keras.optimizers import Adam,SGD,RMSprop

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print(X_train.dtype, X_train.shape, y_train.dtype, y_train.shape)
# Out:
# uint8 (50000, 32, 32, 3) uint8 (50000, 1)

# %%
#load data

plt.imshow(X_train[0])
plt.show()
print(f"label is {y_train[0]}")
# Out:
# label is [6]

# %%
plt.show()
print(f"label is {y_train[1]}")#method broadcasting to normalize data
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

#to categorical conversion
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# label is [9]

# %%
model=Sequential()
model.add(Flatten(input_shape=(32,32,3)))#1st layer
model.add(Dense(128,activation='relu'))#128 neuron 2nd layer
model.add(Dense(10,activation='softmax'))#3rd layer
# compile the model
model.compile(optimizer=SGD(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy']) 
#train the model
res=model.fit(X_train, y_train, epochs=10, batch_size=128,validation_split=0.2)
print("Code executed successfully")
# validation
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Validation loss: {loss}")
print(f"Validation accuracy: {accuracy}")
# Out:
# C:\Users\Raj\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1819 - loss: 2.2457 - val_accuracy: 0.2159 - val_loss: 2.1663
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2470 - loss: 2.1200 - val_accuracy: 0.2588 - val_loss: 2.0887
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2764 - loss: 2.0571 - val_accuracy: 0.2829 - val_loss: 2.0389
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.2979 - loss: 2.0128 - val_accuracy: 0.2901 - val_loss: 2.0018
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3081 - loss: 1.9799 - val_accuracy: 0.3030 - val_loss: 1.9747
# Epoch 6/10
# ...

# %%
model1= Sequential()
model1.add(Flatten(input_shape=(32, 32, 3)))

model1.add(Dense(1024, activation='relu'))
model1.add(Dense(512, activation='relu')) # 1. Dense layer (input)
model1.add(Dense(256, activation='relu'))

 # 1. Flatten layer (input)
model1.add(Dense(10, activation='softmax'))   # 2. Dense layer (single output layer)


# compile the model
model1.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy', metrics=['accuracy'])

res1=model1.fit(X_train, y_train, epochs=10, batch_size=128,validation_split=0.2)
print("Code executed successfully")
# validation
loss, accuracy = model1.evaluate(X_test, y_test)
print(f"Validation loss: {loss}")
print(f"Validation accuracy: {accuracy}")
# Out:
# C:\Users\Raj\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 67ms/step - accuracy: 0.3050 - loss: 1.9348 - val_accuracy: 0.3606 - val_loss: 1.7743
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.3870 - loss: 1.7039 - val_accuracy: 0.4084 - val_loss: 1.6654
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.4237 - loss: 1.6139 - val_accuracy: 0.4125 - val_loss: 1.6427
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 64ms/step - accuracy: 0.4475 - loss: 1.5493 - val_accuracy: 0.4451 - val_loss: 1.5711
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 62ms/step - accuracy: 0.4645 - loss: 1.4940 - val_accuracy: 0.4608 - val_loss: 1.5225
# ...

# %%
model2 = Sequential()
model2.add(Flatten(input_shape=(32, 32, 3))) 

model2.add(Dense(1024, activation='relu'))
model2.add(Dense(512, activation='relu')) # Layer 1: Input layer
model2.add(Dense(256, activation='relu'))   # Layer 2: 1st Hidden layer
model2.add(Dense(128, activation='relu'))   # Layer 3: 2nd Hidden layer
model2.add(Dense(64, activation='relu'))    # Layer 4: 3rd Hidden layer
model2.add(Dense(10, activation='softmax'))    # Layer 5: Output layer

# compile the model
# Using 'Adam' optimizer as an example
model.compile(optimizer=RMSprop(learning_rate=0.001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
res2=model.fit(X_train, y_train, epochs=10, batch_size=128,validation_split=0.2)
print("Code executed successfully")
# validation
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Validation loss: {loss}")
print(f"Validation accuracy: {accuracy}")
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5063 - loss: 1.4006 - val_accuracy: 0.4462 - val_loss: 1.6162
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5085 - loss: 1.3949 - val_accuracy: 0.4464 - val_loss: 1.6239
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5103 - loss: 1.3873 - val_accuracy: 0.4659 - val_loss: 1.5696
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5131 - loss: 1.3787 - val_accuracy: 0.4229 - val_loss: 1.7440
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5119 - loss: 1.3777 - val_accuracy: 0.4132 - val_loss: 1.7156
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5175 - loss: 1.3707 - val_accuracy: 0.4406 - val_loss: 1.6298
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5160 - loss: 1.3669 - val_accuracy: 0.4565 - val_loss: 1.6154
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

# Create a figure and a 2x3 grid of subplots
# 'axes' will be a 2D array: axes[row, col]
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 10))

# Add a main title for the whole figure
fig.suptitle('Model Comparison: 3-Layer vs 1-Layer vs 5-Layer', fontsize=16)

# --- 3-Layer Model (res) ---

# Plot 1: 3-Layer Accuracy
axes[0, 0].plot(res.history['val_accuracy'], label='Val Accuracy', color='blue')
axes[0, 0].plot(res.history['accuracy'], label='Training Accuracy', color='green')
axes[0, 0].legend()
axes[0, 0].set_title('1-Layer(SGD): Training vs Validation Accuracy')
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Accuracy')

# Plot 4: 3-Layer Loss
axes[1, 0].plot(res.history['val_loss'], label='Val Loss', color='blue')
axes[1, 0].plot(res.history['loss'], label='Training Loss', color='green')
axes[1, 0].legend()
axes[1, 0].set_title('1-Layer(SGD): Training vs Validation Loss')
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Loss')

# --- 1-Layer Model (res1) ---

# Plot 2: 1-Layer Accuracy
axes[0, 1].plot(res1.history['val_accuracy'], label='Val Accuracy', color='blue')
axes[0, 1].plot(res1.history['accuracy'], label='Training Accuracy', color='green')
axes[0, 1].legend()
axes[0, 1].set_title('3-Layer(Adam): Training vs Validation Accuracy')
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')

# Plot 5: 1-Layer Loss
axes[1, 1].plot(res1.history['val_loss'], label='Val Loss', color='blue')
axes[1, 1].plot(res1.history['loss'], label='Training Loss', color='green')
axes[1, 1].legend()
axes[1, 1].set_title('3-Layer(Adam): Training vs Validation Loss')
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Loss')

# --- 5-Layer Model (res2) ---

# Plot 3: 5-Layer Accuracy
axes[0, 2].plot(res2.history['val_accuracy'], label='Val Accuracy', color='blue')
axes[0, 2].plot(res2.history['accuracy'], label='Training Accuracy', color='green')
axes[0, 2].legend()
axes[0, 2].set_title('5-Layer(RMSprop): Training vs Validation Accuracy')
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Accuracy')

# Plot 6: 5-Layer Loss
axes[1, 2].plot(res2.history['val_loss'], label='Val Loss', color='blue')
axes[1, 2].plot(res2.history['loss'], label='Training Loss', color='green')
axes[1, 2].legend()
axes[1, 2].set_title('5-Layer(RMSprop): Training vs Validation Loss')
axes[1, 2].set_xlabel('Epochs')
axes[1, 2].set_ylabel('Loss')

# Automatically adjust spacing to prevent titles/labels from overlapping
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust for the main title

# Show the plot
plt.show()
